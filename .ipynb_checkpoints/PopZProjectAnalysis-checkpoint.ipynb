# %%
from Piplines import*
Starter = PiplinesObj(fig2_37c, TimeLapse=False, columns=[(0,1), (0,2), (1,2)])
Starter.DiffuseSignalPipline(plots=['tot-violin'])
# Out:
# Start to process the group of DG50 .
# Processing 79 cells in signal0.
# Start to process the group of DGS50 .
# Processing 35 cells in signal0.
# Processing 33 cells in signal0.
# Start to process the group of TDGS50 .
# Processing 81 cells in signal0.
# info 0.5504575007713881
# info 0.7517009821514156
# info 13.791527876117886
# ttest_ind:            t = 1.34181  p = 0.181754
# ttest_ind:            t = -10.4615  p = 1.71989e-19
# ttest_ind:            t = -11.2395  p = 6.56233e-22
# The analysis is finishing.

# %%
from Piplines import*
Starter = PiplinesObj(fig4, TimeLapse=False, columns=[(0,1)])
Starter.TwoChannelPipline(plots=['lr', 'trace', 'statprofile'])
# Out:
# Start to process the group of NSSCP .
# Processing 107 cells in signal0.
# ...
# Processing 107 cells in signal1.
# ...
# Processing 28 cells in signal0.
# Processing 28 cells in signal1.
# Processing 46 cells in signal0.
# Processing 46 cells in signal1.
# Start to process the group of NSSC .
# Processing 23 cells in signal0.
# Processing 23 cells in signal1.
# Processing 16 cells in signal0.
# Processing 16 cells in signal1.
# Processing 20 cells in signal0.
# Processing 20 cells in signal1.
# Processing 48 cells in signal0.
# Processing 48 cells in signal1.
# The group NSSCP has n= 117 after unipolar PopZ selection.
# info 5.242423422384582
# The group NSSC has n= 107 after unipolar PopZ selection.
# info 0.16768401701178326
# ttest_ind:            t = 7.41673  p = 2.51389e-12
# The analysis is finishing.

# %%
from Piplines import*
Starter = PiplinesObj(fig3, TimeLapse=False, columns=[(0,1), (0,2), (1,2)])
# Starter.DiffuseSignalPipline(plots=['tot-violin'])
Starter.TwoChannelPipline(plots=['lr', 'trace', 'statprofile'])
# Out:
# Start to process the group of PS .
# Processing 42 cells in signal0.
# Processing 42 cells in signal1.
# Processing 56 cells in signal0.
# Processing 56 cells in signal1.
# Processing 41 cells in signal0.
# Processing 41 cells in signal1.
# Processing 41 cells in signal0.
# Processing 41 cells in signal1.
# Processing 59 cells in signal0.
# Processing 59 cells in signal1.
# Processing 16 cells in signal0.
# Processing 16 cells in signal1.
# Start to process the group of PSNC .
# Processing 23 cells in signal0.
# Processing 23 cells in signal1.
# Processing 15 cells in signal0.
# Processing 15 cells in signal1.
# Processing 19 cells in signal0.
# Processing 19 cells in signal1.
# Processing 18 cells in signal0.
# Processing 18 cells in signal1.
# Processing 14 cells in signal0.
# Processing 14 cells in signal1.
# Processing 17 cells in signal0.
# Processing 17 cells in signal1.
# Processing 22 cells in signal0.
# Processing 22 cells in signal1.
# ...

# %%
from Piplines import*
Starter = PiplinesObj(fig2, TimeLapse=False, columns=[(0,1), (0,2), (1,2)])
Starter.DiffuseSignalPipline(plots=['tot-bar'])
# Out:
# Start to process the group of DG50 .
# Processing 68 cells in signal0.
# Processing 81 cells in signal0.
# Start to process the group of DGS50 .
# Processing 45 cells in signal0.
# Processing 46 cells in signal0.
# Processing 42 cells in signal0.
# Start to process the group of TDGS50 .
# Processing 75 cells in signal0.
# Processing 68 cells in signal0.
# info 1.1941471515885937
# info 0.14579319113852995
# info 4.0420503680338
# ttest_ind:            t = 3.48542  p = 0.000570191
# ttest_ind:            t = -4.82998  p = 2.27449e-06
# ttest_ind:            t = -3.67095  p = 0.000287589
# The analysis is finishing.

# %%
from Piplines import*
Starter = PiplinesObj(fig1, TimeLapse=False, columns=[(0,1), (0,2), (1,2)])
Starter.DiffuseSignalPipline(plots=['tot-bar'])
# Out:
# Start to process the group of 116DG .
# Processing 21 cells in signal0.
# Processing 23 cells in signal0.
# Processing 31 cells in signal0.
# Start to process the group of 116DG52 .
# Processing 50 cells in signal0.
# Processing 86 cells in signal0.
# Start to process the group of 116DG50 .
# Processing 45 cells in signal0.
# Processing 46 cells in signal0.
# Processing 42 cells in signal0.
# info 13.3802942173593
# info 6.779370304722114
# info 0.14579319113852995
# ttest_ind:            t = 17.3227  p = 2.82562e-42
# ttest_ind:            t = 18.7238  p = 1.55423e-50
# ttest_ind:            t = 34.9583  p = 1.46798e-88
# The analysis is finishing.
